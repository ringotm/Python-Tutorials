# %%
import pandas as pd

# %%
file = "../Border_Crossing_Project/Border_Crossing_Entry_Data.csv"

# %%
df = pd.read_csv(file, parse_dates=['Date'])

# %%
df.head()
# Out:
#   Port Name State  Port Code            Border       Date  \
# 0     Alcan    AK       3104  US-Canada Border 2020-02-01
# 1     Alcan    AK       3104  US-Canada Border 2020-02-01
# 2     Alcan    AK       3104  US-Canada Border 2020-02-01
# 3     Alcan    AK       3104  US-Canada Border 2020-02-01
# 4     Alcan    AK       3104  US-Canada Border 2020-02-01
#
#                        Measure  Value
# 0  Personal Vehicle Passengers   1414
# 1            Personal Vehicles    763
# 2       Truck Containers Empty    412
# 3        Truck Containers Full    122
# 4                       Trucks    545

# %%
df_Texas_2019_PVP = df.loc[(df['State'] == 'TX') & (df['Date'].dt.year == 2019) & (df['Measure'] == 'Personal Vehicle Passengers')]
df_Texas_2019_PVP.tail(15)
# Out:
#              Port Name State  Port Code            Border       Date  \
# 10103          Del Rio    TX       2302  US-Mexico Border 2019-02-01
# 10105  Tornillo-Fabens    TX       2404  US-Mexico Border 2019-02-01
# 10161  Rio Grande City    TX       2307  US-Mexico Border 2019-02-01
# 10271          El Paso    TX       2402  US-Mexico Border 2019-02-01
# 10391         Progreso    TX       2309  US-Mexico Border 2019-01-01
# 10538       Eagle Pass    TX       2303  US-Mexico Border 2019-01-01
# 10582          El Paso    TX       2402  US-Mexico Border 2019-01-01
# 10656             Roma    TX       2310  US-Mexico Border 2019-01-01
# 10709          Hidalgo    TX       2305  US-Mexico Border 2019-01-01
# 10786  Rio Grande City    TX       2307  US-Mexico Border 2019-01-01
# 10943         Presidio    TX       2403  US-Mexico Border 2019-01-01
# 10968          Del Rio    TX       2302  US-Mexico Border 2019-01-01
# 11057           Laredo    TX       2304  US-Mexico Border 2019-01-01
# ...

# %%
df_Texas_2019_PVP['Date'].value_counts()
# Out:
# 2019-06-01    13
# 2019-07-01    11
# 2019-08-01    11
# 2019-09-01    11
# 2019-10-01    11
# 2019-11-01    11
# 2019-03-01    11
# 2019-04-01    11
# 2019-01-01    11
# 2019-02-01    11
# 2019-12-01    11
# 2019-05-01    11
# Name: Date, dtype: int64

# %%
df_Texas_2019_PVP.loc[df_Texas_2019_PVP['Date'] == '2019-06-01']
# Out:
#             Port Name State  Port Code            Border       Date  \
# 6363          Del Rio    TX       2302  US-Mexico Border 2019-06-01
# 6518  Tornillo-Fabens    TX       2404  US-Mexico Border 2019-06-01
# 6524             Roma    TX       2310  US-Mexico Border 2019-06-01
# 6529  Rio Grande City    TX       2307  US-Mexico Border 2019-06-01
# 6535         Progreso    TX       2309  US-Mexico Border 2019-06-01
# 6541         Presidio    TX       2403  US-Mexico Border 2019-06-01
# 6552           Laredo    TX       2304  US-Mexico Border 2019-06-01
# 6560          Hidalgo    TX       2305  US-Mexico Border 2019-06-01
# 6572          El Paso    TX       2402  US-Mexico Border 2019-06-01
# 6583       Eagle Pass    TX       2303  US-Mexico Border 2019-06-01
# 6591          Del Rio    TX       2302  US-Mexico Border 2019-06-01
# 6599      Brownsville    TX       2301  US-Mexico Border 2019-06-01
# 7134             Roma    TX       2310  US-Mexico Border 2019-06-01
#
# ...

# %%
df_Texas_2019_PVP.shape
# Out:
# (134, 7)

# %%
df_Texas_2019_PVP.pivot(index='Date', columns = 'Port Name', values = 'Value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e20385f5c3bc> in <module>
# ----> 1 df_Texas_2019_PVP.pivot(index='Date', columns = 'Port Name', values = 'Value')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     448         else:
#     449             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 450     return indexed.unstack(columns)
#     451
#     452
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
# ...
